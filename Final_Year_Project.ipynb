# %% [markdown]
# <a href="https://colab.research.google.com/github/arpan000/Final-Year-Project/blob/main/Final_Year_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Lets, we have total 5 features(sensors)- A, B, C, D, E. A has normal range for 80-120 B has normal range for 60-120. A has normal range for 80-120.
c has normal range for 60-80.
My sensors will send data to me in regular case as a bit value 0(Gsm mode). In abnormal case data will come as +1 or -1.

'''
import time
import io
import geocoder
import requests

# %%
l_A=[] #need to create in a protected separate file amd to ise them

if A!=0 and l_A.count()<5:
for i in range(0, 5):
#sensor data will be in separated buffer foe each features
#buffer = io.BytesIO(b"Hello, world!")
data = buffer.getvalue()
l_A.append(data)
if i<4:
time.sleep(5)
if A==0:
l_A.clear()
if A!=0 and l_A.count()>=5:
# activate sensors for parameter assosiated with A for ex- B, C
if B!=0 and l_B.count()<5:
for i in range(0, 5):
#buffer = io.BytesIO(b"Hello, world!")
data = buffer.getvalue()
l_B.append(data)
if i<4:
  time.sleep(5)

else:
#case thoda cesual hay
if A!=0 and l_B.count()>0:
#now we need to send l_A nad l_B
request = requests.Request('POST', 'http://localhost:8080/data', data='Your data')
response = requests.send(request)
data = response.content


g = geocoder.ip('me')
latitude = g.latlng[0]
longitude = g.latlng[1]

# %%
import matplotlib.pyplot as plt

E=50
E_amp=100
#k=volume of data
#d=distance among sensor and local data center

d=1
y1_values = []

y2_values = []

opt1 = [32, 35, 39, 41, 47, 56, 64]
for k in opt1:
  E_tx= E*k + E_amp*k*d*d
  E_rx= E*k
  E_total= E_tx+E_rx
  y1_values.append(E_total)

opt1 = [20, 24 ,28, 32, 34 ,38, 42]
for k in opt1:
  E_tx= E*k + E_amp*k*d*d
  E_rx= E*k
  E_total= E_tx+E_rx
  y2_values.append(E_total)


# Sample data
x_values = [4000, 5000, 6000,7000,8000, 9000, 10000]
print(y1_values)
print(y2_values)

# Plotting
plt.plot(x_values, y1_values, label='Energy with data optimization')
plt.plot(x_values, y2_values, label='Energy without data optimization')

# Adding labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Two Sets of Values')

# Adding legend
plt.legend()

# Displaying the plot
plt.show()
# Out:
# [6400, 7000, 7800, 8200, 9400, 11200, 12800]
# [4000, 4800, 5600, 6400, 6800, 7600, 8400]
